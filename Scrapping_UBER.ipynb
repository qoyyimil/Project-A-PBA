# %% [markdown]
# <a href="https://colab.research.google.com/github/qoyyimil/Project-A-PBA/blob/main/Scrapping_UBER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas openpyxl requests beautifulsoup4 lxml
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os
import time
import random
from urllib.parse import urlparse

import pandas as pd
import requests
from bs4 import BeautifulSoup
from requests.exceptions import RequestException

# %%
# KONFIGURASI
EXCEL_PATH = "/content/Link Berita - Kelompok 6.xlsx"
SHEET_NAME = "UBER"
URL_COLUMN = "Link"
OUTPUT_CSV = "/content/hasil_scrape_UBER.csv"

# Header agar tidak mudah diblokir server
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "id,en;q=0.9",
}

# %%
# FUNGSI UTILITAS
def is_valid_url(url: str) -> bool:
    if not isinstance(url, str):
        return False
    u = url.strip()
    if not (u.startswith("http://") or u.startswith("https://")):
        return False
    parsed = urlparse(u)
    return bool(parsed.scheme) and bool(parsed.netloc)

def extract_title(soup: BeautifulSoup) -> str:
    # Prioritas: og:title -> twitter:title -> <h1> -> <title>
    og = soup.find("meta", attrs={"property": "og:title"})
    if og and og.get("content"):
        return og["content"].strip()

    tw = soup.find("meta", attrs={"name": "twitter:title"})
    if tw and tw.get("content"):
        return tw["content"].strip()

    h1 = soup.find("h1")
    if h1 and h1.get_text(strip=True):
        return h1.get_text(strip=True)

    title = soup.find("title")
    if title and title.get_text(strip=True):
        return title.get_text(strip=True)

    return "Judul tidak ditemukan"

def extract_text(soup: BeautifulSoup) -> str:
    # Ambil semua paragraf yang ada teksnya
    paragraphs = soup.find_all("p")
    texts = [
        p.get_text(separator=" ", strip=True)
        for p in paragraphs
        if p.get_text(strip=True)
    ]
    article_text = " ".join(texts).strip()

    # Fallback: meta description jika paragraf kosong
    if not article_text:
        for attrs in ({"name": "description"}, {"property": "og:description"}):
            meta = soup.find("meta", attrs=attrs)
            if meta and meta.get("content"):
                return meta["content"].strip()

    return article_text

def scrape_article(url: str, timeout: int = 20):
    """
    Kembalikan: (title, text, status_code, error_msg)
    """
    try:
        resp = requests.get(url, headers=HEADERS, timeout=timeout)
        status = resp.status_code

        if status != 200:
            return None, None, status, f"Status code {status}"

        soup = BeautifulSoup(resp.content, "html.parser")
        title = extract_title(soup)
        text = extract_text(soup)

        if not text:
            return title, "", status, "Empty article text"

        return title, text, status, ""
    except RequestException as e:
        return None, None, None, f"RequestException: {e}"
    except Exception as e:
        return None, None, None, f"Exception: {e}"

# %%
# MAIN
def main():
    # 1) Baca Excel
    try:
        df = pd.read_excel(EXCEL_PATH, sheet_name=SHEET_NAME)  # engine=openpyxl otomatis
    except FileNotFoundError:
        print(f"File tidak ditemukan: {EXCEL_PATH}")
        return
    except ValueError as e:
        # Biasanya saat sheet tidak ada
        print(f"Gagal membuka sheet '{SHEET_NAME}': {e}")
        return
    except Exception as e:
        print(f"Error membaca Excel: {e}")
        return

    # 2) Validasi kolom
    if URL_COLUMN not in df.columns:
        print(f"Kolom '{URL_COLUMN}' tidak ditemukan di sheet '{SHEET_NAME}'. Kolom tersedia: {list(df.columns)}")
        return

    # 3) Siapkan daftar URL + optional kolom No/PJ
    urls = []
    for _, row in df.iterrows():
        url = row[URL_COLUMN]
        if is_valid_url(url):
            urls.append({
                "No": row["No"] if "No" in df.columns else None,
                "PJ": row["PJ"] if "PJ" in df.columns else None,
                "URL": url.strip()
            })

    if not urls:
        print("Tidak ada URL valid pada kolom 'Link'.")
        return

    # 4) (Opsional) Hilangkan duplikasi URL agar hemat waktu
    seen = set()
    unique_rows = []
    for r in urls:
        if r["URL"] not in seen:
            seen.add(r["URL"])
            unique_rows.append(r)
    urls = unique_rows

    print(f"Total URL valid untuk di-scrape: {len(urls)}")
    results = []

    # 5) Scrape satu per satu
    for i, item in enumerate(urls, start=1):
        url = item["URL"]
        print(f"[{i}/{len(urls)}] Scraping: {url}")

        title, text, status, err = scrape_article(url)
        results.append({
            "No": item["No"],
            "PJ": item["PJ"],
            "Original_URL": url,
            "Judul_Artikel_Scraped": title if title else "",
            "Teks_Artikel_Scraped": text if text else "",
            "Status_Code": status if status is not None else "",
            "Error": err
        })

        # Jeda acak biar sopan
        time.sleep(random.uniform(1.0, 2.5))

    # 6) Simpan ke CSV
    out_df = pd.DataFrame(results)
    out_df.to_csv(OUTPUT_CSV, index=False, encoding="utf-8")
    print(f"Selesai. Hasil disimpan ke: {OUTPUT_CSV}")

if __name__ == "__main__":
    main()
# Out:
# Total URL valid untuk di-scrape: 174
# [1/174] Scraping: https://edition.cnn.com/2025/09/11/tech/us-sues-uber-alleging-disability-discrimination
# [2/174] Scraping: https://edition.cnn.com/2025/03/04/business/self-driving-uber-waymo-texas
# [3/174] Scraping: https://edition.cnn.com/2025/05/14/tech/uber-route-share-cheaper-carpool-service
# [4/174] Scraping: https://edition.cnn.com/2025/07/24/tech/uber-women-preferences-us-launch
# [5/174] Scraping: https://edition.cnn.com/2023/05/17/tech/uber-teen-accounts
# [6/174] Scraping: https://edition.cnn.com/2024/05/15/tech/uber-shuttle-airport-concert-annual-product-update
# [7/174] Scraping: https://edition.cnn.com/2022/02/16/tech/uber-ratings-update
# [8/174] Scraping: https://edition.cnn.com/2024/03/18/business/uber-australia-taxi-drivers-compensation
# [9/174] Scraping: https://edition.cnn.com/2024/10/02/business/uber-eats-accident-lawsuit
# [10/174] Scraping: https://www.cnn.com/2021/03/16/tech/uber-uk-vacation-pensions-drivers
# [11/174] Scraping: https://www.cnn.com/2021/04/19/tech/uber-lyft-drivers-stimulus
# [12/174] Scraping: https://www.cnn.com/2021/04/28/cars/uber-rent-car
# [13/174] Scraping: https://www.cnn.com/2022/10/19/tech/uber-advertising-division
# [14/174] Scraping: https://www.cnn.com/2023/03/29/tech/lyft-leadership-change
# [15/174] Scraping: https://www.cnn.com/2023/08/01/tech/uber-earnings
# [16/174] Scraping: https://www.cnn.com/2022/06/21/tech/uber-restarting-shared-rides
# [17/174] Scraping: https://www.cnn.com/2022/03/12/business/uber-gas-prices-surcharge
# [18/174] Scraping: https://www.cnn.com/2021/05/27/tech/uber-union-uk
# [19/174] Scraping: https://www.cnn.com/2022/08/02/tech/uber-q2-earnings
# [20/174] Scraping: https://www.cnn.com/video/news/2014/12/10/uber-legal-and-regulatory-trouble.cnnmoney
# [21/174] Scraping: https://www.cnn.com/2019/04/25/tech/uber-public-transportation
# [22/174] Scraping: https://www.cnn.com/2023/03/07/tech/uber-airport-features
# [23/174] Scraping: https://www.cnn.com/2023/01/19/business/uber-city-car
# [24/174] Scraping: https://www.cnn.com/2019/07/09/tech/uber-comfort-and-helicopter-launch
# [25/174] Scraping: https://www.cnn.com/2020/09/08/tech/uber-climate-change
# [26/174] Scraping: https://www.cnn.com/2020/01/07/tech/uber-hyundai-flying-taxis-trnd
# [27/174] Scraping: https://www.cnn.com/2019/07/01/tech/uber-bikes-scooters
# [28/174] Scraping: https://www.cnn.com/2019/04/26/tech/uber-public-transportation-update
# [29/174] Scraping: https://www.cnn.com/2019/05/07/tech/uber-driver-strike-ipo
# [30/174] Scraping: https://www.cnn.com/2019/05/08/tech/uber-strike
# [31/174] Scraping: https://www.cnn.com/2025/09/23/americas/mexico-city-women-only-taxis-as-equals-intl-cmd
# [32/174] Scraping: https://www.cnn.com/business/live-news/uber-lyft-strike-may-2019
# [33/174] Scraping: https://www.cnn.com/2020/07/21/tech/uber-uk-court-case-blm
# [34/174] Scraping: https://www.cnn.com/2014/06/11/travel/taxi-protests-uber
# [35/174] Scraping: https://www.cnn.com/2019/06/14/tech/postmates-blitz-up-worker-protest
# [36/174] Scraping: https://www.cnn.com/2021/10/07/tech/uber-racism-uk-lawsuit-facial-recognition
# [37/174] Scraping: https://www.cnn.com/2021/06/16/business/uber-lyft-drivers-labor-fight
# [38/174] Scraping: https://www.cnn.com/2020/10/08/tech/proposition-22-california
# [39/174] Scraping: https://www.cnn.com/2019/12/18/tech/tech-workers-agitating-in-2019
# [40/174] Scraping: https://www.cnn.com/2015/06/25/world/gallery/french-taxis-uber-protest
# [41/174] Scraping: https://www.cnn.com/2020/07/23/business/lyft-drivers-ppe-gig-app
# [42/174] Scraping: https://www.cnn.com/2021/02/19/tech/uber-uk-workers
# [43/174] Scraping: https://www.cnn.com/2019/07/16/tech/uber-sexual-harassment-purple-campaign
# [44/174] Scraping: https://www.cnn.com/2020/07/12/business/strike-for-black-lives-union-wages
# [45/174] Scraping: https://www.cnn.com/2024/05/19/business/uber-lyft-drivers-pay-minnesota
# [46/174] Scraping: https://www.cnn.com/2019/05/03/tech/uber-lyft-driver-strike
# [47/174] Scraping: https://www.cnn.com/2020/07/28/business/uber-lyft-unemployment
# [48/174] Scraping: https://www.cnn.com/2021/04/02/business/uber-blind-passenger-arbitration-trnd
# [49/174] Scraping: https://www.cnn.com/2020/08/20/tech/uber-lyft-california-shutdown
# [50/174] Scraping: https://www.cnn.com/2020/08/01/us/garrett-foster-killing-austin-protest
# [51/174] Scraping: https://www.cnn.com/2019/11/06/tech/uber-stock-lockup
# [52/174] Scraping: https://www.cnn.com/2019/04/18/tech/uber-fake-driver-safety-alerts
# [53/174] Scraping: https://www.cnn.com/2025/09/06/politics/washington-dc-delivery-drivers-immigration-arrests
# [54/174] Scraping: https://edition.cnn.com/2020/08/16/tech/uber-lyft-california-suspension
# [55/174] Scraping: https://www.cnn.com/2021/03/11/tech/uber-lyft-sharing-safety-program
# [56/174] Scraping: https://www.cnn.com/2019/07/24/perspectives/uber-lyft-employees-ab5
# [57/174] Scraping: https://www.cnn.com/2019/07/15/tech/uber-diversity-report-2019
# [58/174] Scraping: https://www.cnn.com/2020/11/15/tech/gig-worker-classification-post-prop-22
# [59/174] Scraping: https://www.cnn.com/2021/01/12/tech/california-prop-22-lawsuit
# [60/174] Scraping: https://www.cnn.com/2020/01/21/tech/uber-california-drivers-rates
# [61/174] Scraping: https://www.cnn.com/2018/09/28/tech/uber-driver-sexual-assault
# [62/174] Scraping: https://www.cnn.com/2020/01/28/tech/just-eat-mcdonalds-uber-eats
# [63/174] Scraping: https://www.cnn.com/2022/06/30/tech/uber-safety-report
# [64/174] Scraping: https://www.cnn.com/2022/07/14/business/uber-sexual-assault-safety-lawsuit
# [65/174] Scraping: https://www.cnn.com/2022/08/30/tech/uber-safety-update
# [66/174] Scraping: https://www.cnn.com/2019/01/21/tech/uber-investigations-unit-report
# [67/174] Scraping: https://www.cnn.com/2018/06/01/us/felons-driving-for-uber-invs
# [68/174] Scraping: https://www.cnn.com/2021/03/12/business/uber-driver-mask-dispute-california-trnd
# [69/174] Scraping: https://www.cnn.com/2019/04/09/tech/uber-fake-driver-scheme-lawsuit
# [70/174] Scraping: https://www.cnn.com/2019/12/05/tech/uber-safety-report
# [71/174] Scraping: https://www.cnn.com/2022/12/07/tech/uber-motional-self-driving-vegas
# [72/174] Scraping: https://www.cnn.com/2024/08/23/business/uber-robotaxi-gm-cruise
# [73/174] Scraping: https://www.cnn.com/2022/11/01/business/self-driving-industry-ctrp
# [74/174] Scraping: https://www.cnn.com/2022/06/07/tech/uber-waymo-self-driving-deal
# [75/174] Scraping: https://www.cnn.com/2019/04/18/tech/uber-toyota-softbank-self-driving
# [76/174] Scraping: https://www.cnn.com/2018/11/02/tech/uber-self-driving-tests
# [77/174] Scraping: https://www.cnn.com/2020/09/18/cars/uber-vasquez-charged
# [78/174] Scraping: https://www.cnn.com/2023/10/03/tech/driverless-car-pedestrian-injury
# [79/174] Scraping: https://www.cnn.com/world/driverless-car-race-abu-dhabi-spc
# [80/174] Scraping: https://www.cnn.com/2019/11/19/tech/uber-crash-ntsb
# [81/174] Scraping: https://www.cnn.com/2025/05/01/business/first-driverless-semis-started-regular-routes
# [82/174] Scraping: https://www.cnn.com/2025/06/18/business/waymo-new-york-city
# [83/174] Scraping: https://www.cnn.com/2021/03/05/cars/cavnue-self-driving-lanes
# [84/174] Scraping: https://www.cnn.com/2022/08/15/business/tesla-fsd-california-dmv
# [85/174] Scraping: https://www.cnn.com/2022/10/26/business/ford-argo-ai-vw-shut-down
# [86/174] Scraping: https://www.cnn.com/2019/04/10/tech/uber-ipo
# [87/174] Scraping: https://www.cnn.com/2019/06/12/tech/uber-melbourne-flying-taxis
# [88/174] Scraping: https://www.cnn.com/2019/04/16/tech/uber-saudi-arabia-women-preferred
# [89/174] Scraping: https://www.cnn.com/2020/02/13/tech/uber-1-800-number-arizona
# [90/174] Scraping: https://www.cnn.com/2019/08/07/tech/uber-lyft-nyc-limits
# [91/174] Scraping: https://www.cnn.com/2021/06/16/tech/uber-software-bug-drivers-charged
# [92/174] Scraping: https://www.cnn.com/2020/02/09/us/fake-uber-lyft-driver-alleged-prowler-trnd
# [93/174] Scraping: https://www.cnn.com/2024/04/16/us/ohio-uber-driver-murder-charge
# [94/174] Scraping: https://www.cnn.com/2020/02/18/us/new-orleans-uber-shooting
# [95/174] Scraping: https://www.cnn.com/2019/04/09/us/uber-driver-attempted-burglary-trnd
# [96/174] Scraping: https://www.cnn.com/2019/04/02/us/usc-uber-killing-law
# [97/174] Scraping: https://www.cnn.com/2019/07/19/business/wells-fargo-dreamers-daca-lawsuit-auto-lending
# [98/174] Scraping: https://www.cnn.com/business/article/sitemap-2023-7.html
# [99/174] Scraping: https://www.cnn.com/us/article/sitemap-2022-8.html
# [100/174] Scraping: https://www.cnbc.com/2025/09/10/uber-eats-pipe-loans-restaurants.html
# [101/174] Scraping: https://www.cnbc.com/2025/07/23/uber-women-drivers-riders.html
# [102/174] Scraping: https://www.cnbc.com/2025/05/14/new-uber-features-include-a-way-to-avoid-surge-pricing.html
# [103/174] Scraping: https://www.cnbc.com/2025/06/10/uber-taps-ai-firm-wayve-to-pilot-fully-driverless-rides-in-the-uk.html
# [104/174] Scraping: https://www.cnbc.com/2025/09/10/uber-to-add-blade-helicopter-rides-through-expanded-joby-partnership-.html
# [105/174] Scraping: https://www.cnbc.com/2025/04/28/uber-raises-in-office-requirement-to-3-days-claws-back-remote-workers.html
# [106/174] Scraping: https://www.cnbc.com/2025/07/17/uber-lucid-robotaxi-partnership-300-million-20000-nuro.html
# [107/174] Scraping: https://www.cnbc.com/2025/05/16/uber-sabbatical-shift-opens-new-front-in-worker-flexibility-crackdown.html
# [108/174] Scraping: https://www.cnbc.com/2025/06/24/uber-waymo-robotaxi-service-opens-to-passengers-in-atlanta.html
# [109/174] Scraping: https://www.cnbc.com/2018/08/08/transgender-uber-driver-suspended-tech-oversight-facial-recognition.html
# [110/174] Scraping: https://www.cnbc.com/2016/02/04/puppies-and-other-secrets-to-ubers-success-commentary.html
# [111/174] Scraping: https://www.cnbc.com/2017/02/23/two-angel-investors-in-uber-say-efforts-to-change-company-culture-from-within-fell-on-deaf-ears.html
# [112/174] Scraping: https://www.cnbc.com/2025/06/02/uber-delivery-chief-gore-coty-leaving-almost-13-years-at-company.html
# [113/174] Scraping: https://www.cnbc.com/2025/02/05/uber-opens-interest-list-for-waymo-robotaxi-rides-in-austin.html
# [114/174] Scraping: https://www.cnbc.com/2024/05/15/uber-go-get-uber-announces-uber-shuttle-uber-caregiver-costco-perks.html
# [115/174] Scraping: https://www.cnbc.com/2025/03/04/waymo-uber-begin-offering-robotaxi-rides-in-austin-ahead-of-sxsw.html
# [116/174] Scraping: https://www.cnbc.com/2023/05/17/uber-will-let-you-book-rides-without-app-request-car-seats-and-more.html
# [117/174] Scraping: https://www.cnbc.com/2023/10/26/uber-begins-offering-rides-in-self-driving-waymo-cars.html
# [118/174] Scraping: https://www.cnbc.com/2022/05/16/uber-update-lets-you-book-party-buses-electric-vehicles.html
# [119/174] Scraping: https://www.cnbc.com/2021/10/06/uber-can-now-track-your-flight-so-a-ride-home-is-ready-when-you-land.html
# [120/174] Scraping: https://www.cnbc.com/2024/12/06/uber-offers-robotaxi-rides-in-abu-dhabi-partnership-with-weride.html
# [121/174] Scraping: https://www.cnbc.com/2014/06/05/states-warn-of-rideshare-risks-for-passengers.html
# [122/174] Scraping: https://www.cnbc.com/2022/03/02/uber-giving-free-rides-between-ukraine-border-and-two-polish-cities.html
# [123/174] Scraping: https://www.cnbc.com/2019/05/15/new-premium-uber-black-feature-lets-you-request-a-quiet-driver.html
# [124/174] Scraping: https://www.cnbc.com/2019/04/13/uber-is-way-more-complicated-than-lyft-and-investors-shouldnt-value-them-the-same-way.html
# [125/174] Scraping: https://www.cnbc.com/2018/06/15/chinese-uber-rival-didi-chuxing-is-set-to-launch-in-australia.html
# [126/174] Scraping: https://www.cnbc.com/2016/09/25/uber-researching-new-vertical-takeoff-ride-offering-says-product-head-jeff-holden.html
# [127/174] Scraping: https://www.cnbc.com/2025/07/15/baidu-strikes-deal-to-bring-its-driverless-cars-to-uber-globally.html
# [128/174] Scraping: https://www.cnbc.com/2024/10/08/uber-offers-option-of-only-full-electric-vehicles-launches-ai-chatbot.html
# [129/174] Scraping: https://www.cnbc.com/2024/07/31/uber-to-start-using-byd-cars-in-europe-latin-america-and-develop-autonomous-capable-vehicles.html
# [130/174] Scraping: https://www.cnbc.com/2015/06/17/ubers-self-driving-car-future-vs-california-decision-today.html
# [131/174] Scraping: https://www.cnbc.com/2018/06/27/how-uber-won-the-battle-in-london-for-a-license.html
# [132/174] Scraping: https://www.cnbc.com/2017/03/09/what-ubers-future-coo-must-do-to-fix-the-company-commentary.html
# [133/174] Scraping: https://www.cnbc.com/2017/08/03/what-silicon-valley-can-learn-from-ubers-rise-and-fall.html
# [134/174] Scraping: https://www.cnbc.com/2017/02/24/uber-were-not-behind-calls-to-investigate-susan-fowlers-personal-life.html
# [135/174] Scraping: https://www.cnbc.com/2018/02/27/uber-svp-of-leadership-and-strategy-frances-frei-is-leaving.html
# [136/174] Scraping: https://www.cnbc.com/amp/2017/12/06/with-just-her-words-susan-fowler-brought-uber-to-its-knees.html
# [137/174] Scraping: https://www.cnbc.com/2021/02/19/uk-supreme-court-rules-uber-drivers-are-workers-not-contractors.html
# [138/174] Scraping: https://www.nbcnews.com/news/world/uber-pays-178-million-end-legal-fight-australian-taxi-drivers-rcna143820
# [139/174] Scraping: https://www.nbcnews.com/business/business-news/5-new-uber-features-know-way-avoid-surge-pricing-rcna206823
# [140/174] Scraping: https://www.nbcnews.com/tech/tech-news/ex-uber-employees-are-being-surprised-big-tax-bills-they-n1233699
# [141/174] Scraping: https://www.nbcnews.com/tech/tech-news/former-uber-driver-was-employee-rules-california-department-n424976
# [142/174] Scraping: https://www.nbcnews.com/news/us-news/uber-says-it-won-t-change-driver-background-checks-after-n523786
# [143/174] Scraping: https://www.nbcnews.com/business/consumer/states-warn-rideshare-risks-passengers-n116736
# [144/174] Scraping: https://www.nbcnews.com/business/autos/greyball-software-yet-another-black-eye-uber-doj-launches-investigation-n755491
# [145/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-accused-intentionally-overcharging-passengers-millions-dollars-n764626
# [146/174] Scraping: https://www.nbcnews.com/tech/tech-news/it-s-yet-another-bad-week-uber-its-finance-head-n767051
# [147/174] Scraping: https://www.nbcnews.com/think/opinion/uber-s-second-quarter-losses-another-red-flag-amazon-transportation-ncna1042396
# [148/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-s-storm-europe-court-case-office-raids-n436091
# [149/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-gets-18-month-london-license-winning-court-appeal-rcna141
# [150/174] Scraping: https://www.nbcnews.com/news/world/uber-drivers-are-workers-u-k-supreme-court-rules-n1258314
# [151/174] Scraping: https://www.nbcnews.com/news/us-news/uber-reports-141-rapes-2020-even-sexual-assault-incidents-declined-pan-rcna36287
# [152/174] Scraping: https://www.nbcnews.com/nightly-news/video/nbc-news-exclusive-uber-shares-surprising-safety-findings-74595909853
# [153/174] Scraping: https://www.nbcnews.com/news/uber-faces-suit-women-alleging-sexual-assault-drivers-rcna38439
# [154/174] Scraping: https://www.nbcnews.com/tech/innovation/uber-introduces-new-safety-features-including-911-access-its-app-n865161
# [155/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-drivers-drug-mules-connect-rcna38464
# [156/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-riders-drivers-share-fears-about-safety-after-company-releases-n1097446
# [157/174] Scraping: https://www.nbcnews.com/news/us-news/amid-scrutiny-uber-says-it-will-focus-more-safety-n270456
# [158/174] Scraping: https://www.nbcnews.com/news/world/uber-loses-license-london-over-safety-concerns-n1090411
# [159/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-test-recording-audio-trips-effort-improve-security-n1086811
# [160/174] Scraping: https://www.nbcnews.com/news/us-news/uber-unveils-new-safety-measures-wake-college-student-s-murder-n995611
# [161/174] Scraping: https://www.nbcnews.com/news/us-news/uber-reveals-widespread-sexual-assault-problem-including-hundreds-reports-rape-n1096411
# [162/174] Scraping: https://www.nbcnews.com/nightly-news/video/inside-uber-s-special-unit-investigating-sexual-assault-allegations-74664005588
# [163/174] Scraping: https://www.nbcnews.com/news/us-news/women-sue-uber-not-warning-sexual-assaults-fake-drivers-n992506
# [164/174] Scraping: https://www.nbcnews.com/dateline/video/uber-reveals-thousands-of-sexual-assault-claims-in-safety-report-74623557577
# [165/174] Scraping: https://www.nbcnews.com/news/us-news/former-uber-security-chief-found-guilty-concealing-data-breach-rcna50967
# [166/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-agrees-148-million-settlement-states-over-data-breach-n913371
# [167/174] Scraping: https://www.nbcnews.com/tech/security/can-uber-trust-hackers-who-deleted-stolen-data-experts-weigh-n823296
# [168/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-paid-hackers-hid-data-breach-affecting-57-million-people-n823121
# [169/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-battles-privacy-concerns-over-god-view-tool-n251691
# [170/174] Scraping: https://www.nbcnews.com/tech/tech-news/under-pressure-uber-hires-privacy-czar-launches-audit-n252581
# [171/174] Scraping: https://www.nbcnews.com/news/us-news/uber-pay-20m-settlement-drivers-which-one-expert-sees-mostly-n982561
# [172/174] Scraping: https://www.nbcnews.com/tech/tech-news/uber-grants-uk-drivers-worker-status-losing-major-labor-battle-rcna431
# [173/174] Scraping: https://www.nbcnews.com/news/world/uber-made-big-promises-kenya-drivers-say-it-s-ruined-n1247964
# [174/174] Scraping: https://www.nbcnews.com/tech/tech-news/inside-place-where-uber-tries-make-nice-its-drivers-n749031
# Selesai. Hasil disimpan ke: /content/hasil_scrape_UBER.csv
